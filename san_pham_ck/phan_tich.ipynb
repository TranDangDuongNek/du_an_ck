# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("du_lieu_vay.csv")
df.tail()
# Out:
#      ACTIONTYPE  ACTIONDATE  ASSISTANCETYPE  RECORDTYPE        FAIN  \
# 2823          A    20201114               7           2  9119518206
# 2824          A    20201114               7           2  9119988207
# 2825          A    20201114               7           2  9120028209
# 2826          A    20201114               7           2  9120168205
# 2827          A    20201114               7           2  9120308210
#
#       AWARDMODIFICATIONAMENDMENTNUM  URI  CORRECTIONLATEDELETEIND  \
# 2823                              1  NaN                      NaN
# 2824                              1  NaN                      NaN
# 2825                              1  NaN                      NaN
# 2826                              1  NaN                      NaN
# 2827                              1  NaN                      NaN
#
#       FISCALYEARANDQTRCORRECTION     SAI_NUM  ...  \
# 2823                         NaN  SAI Exempt  ...
# 2824                         NaN  SAI Exempt  ...
# ...
